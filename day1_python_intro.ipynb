# %%
# 🐍 Day 1:

# The Simplest Python Program: Print Function

# Print a welcoming message
print("Hello, Welcome to Vision Board")

# Print the mission statement
print('We are here to become future data engineer')

# Python as a Calculator: Basic Arithmetic Operations

# Addition
print(5 + 2)

# Subtraction
print(5 - 2)

# Multiplication
print(5 * 2)

# True Division
print(5 / 2)

# Floor Division
print(5 // 2)

# Exponentiation
print(5 ** 2)
