# %% [markdown]
# ## Operator and its type

# %%
5 + 3 #5 and 3 are operand as we are applying + operator on these number
# Out:
# 8

# %% [markdown]
# ### Arithmetic operator

# %%
5 + 3
# Out:
# 8

# %%
5 - 3
# Out:
# 2

# %%
5 * 3
# Out:
# 15

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5**3
# Out:
# 125

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %% [markdown]
# ### Assignment Operator

# %%
X = 5

# %%
X = X + 3

# %%
X
# Out:
# 8

# %%
X += 3

# %%
X
# Out:
# 11

# %%
X -= 3

# %%
X
# Out:
# 8

# %%
 X *= 3

# %%
print(X)
# Out:
# 24

# %%
X /= 3

# %%
X
# Out:
# 8.0

# %%
 X //= 3

# %%
X **= 2

# %%
X
# Out:
# 4.0

# %% [markdown]
# ### Bitwise Operator

# %%
A = 10
B = 4
A & B
# Out:
# 0

# %%
#Binary of 12 = 1100
#12/2 = 6 0
#6/2 =  3 0
#3/2 =  1 1
#1/2 =  0 1

# %%
#4/2 = 2 0
#2/2 = 1 0
#1/2 = 0 1

# %%
A = 10 #1010
B = 4  #0100
A & B  #0000
# Out:
# 0
